# %%
import functions_stanza

# %%
# %load_ext autoreload
# %autoreload 2

# %%
functions_stanza.nlp_ro("În tot acest timp Abraham așteptă timid cîțiva pași mai în spate, arătînd exact ca managerul care fusese cîndva.")

# %%
import pandas as pd

# %%
df = pd.read_csv("background/concordance_preloaded_europarl7_ro_20260319114627.csv")

# %%
words = df["KWIC"]

# %%
prefixes = []

for word in words:
    prefixes.append(word.split("î")[0])

unique_prefixes = pd.Series(prefixes).unique()

# %%
unique_prefixes

# %%
for word in words:
    if word.startswith("agroî"):
        print(word)

# %%
functions_stanza.convert_sentence_to_new_orthography(
    "În tot acest timp Abraham așteptă timid cîțiva pași mai în spate, arătînd exact ca managerul care fusese cîndva.Înteleg."
)

# %%
import re

# %%
re.sub(r'(?<=\w)î(?=\w)', 'â', "rîzînd")
